# %% [markdown]
# # Recreating the most basic ML Model ever: Linear Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.animation as animation

# %% [markdown]
# ## Loss function

# %%
def MSE(y_true, y_pred):
    n = len(y_true)
    return 1/n * ((y_true - y_pred)**2).sum()

# %% [markdown]
# ## Loss Gradient

# %%
def gradient_MSE_coef_(X, y, coef_, intercept_):
    n = len(y)
    return 2/n * (X * (coef_ * X + intercept_ - y)).sum()

# %%
def gradient_MSE_intercept_(X, y, coef_, intercept_):
    n = len(y)
    return 2/n * (coef_ * X + intercept_ - y).sum()

# %% [markdown]
# ## Gradient Descent

# %%
def batch_gradient_descent(X, y, coef_=np.random.rand(), intercept_=np.random.rand(), iterations=5, learning_rate=0.03):
    for i in range(iterations):
        y_pred = coef_ * X + intercept_

        loss = MSE(y, y_pred)
        gradient_coef_ = gradient_MSE_coef_(X, y, coef_, intercept_)
        gradient_intercept_ = gradient_MSE_intercept_(X, y, coef_, intercept_)

        coef_ = coef_ - learning_rate * gradient_coef_
        intercept_ = intercept_ - learning_rate * gradient_intercept_

        if gradient_MSE_coef_(X, y, coef_, intercept_)**2 + gradient_MSE_intercept_(X, y, coef_, intercept_)**2 < 1e-4:
            break

    return coef_, intercept_

# %% [markdown]
# ## Linear Regression class

# %%
class LinearRegression():
    def __init__(self, coef_=np.random.rand(), intercept_=np.random.rand()):
        self.coef_ = coef_
        self.intercept_ = intercept_

    def fit(self, training_data, validation_data, epochs=1, loss=MSE, optimizer=batch_gradient_descent):
        (X, y) = training_data
        (X_val, y_val) = validation_data
        history = [[self.coef_, self.intercept_]]

        for epoch in range(1, epochs + 1):
            print(f'Epoch {epoch}/{epochs}:', end=' ')
            self.coef_, self.intercept_ = optimizer(X, y, self.coef_, self.intercept_)
            history.append([self.coef_, self.intercept_])
            print(f"loss: {loss(y, self.coef_ * X + self.intercept_)}     val_loss: {loss(y_val, self.coef_ * X_val + self.intercept_)}")

        return history

    def predict(self, X):
        return self.coef_ * X + self.intercept_

    def evaluate(self, validation_data):
        X_val, y_val = validation_data
        return MSE(y_val, self.coef_ * X_val + self.intercept_)

# %% [markdown]
# # Testing Linear Regression on a small dataset

# %%
X = np.random.rand(1000, 1)
y = 4 + 3 * X + .1*np.random.randn(1000, 1)
X_val = np.random.rand(300, 1)
y_val = 4 + 3 * X_val + .1*np.random.randn(300, 1)

# %%
lr = LinearRegression()

# %%
history = lr.fit(training_data=(X, y), validation_data=(X_val, y_val), epochs=100)
# Out:
# Epoch 1/100: loss: 11.899342773485051     val_loss: 11.739269619926148
# Epoch 2/100: loss: 5.405973007736397     val_loss: 5.325456437421491
# Epoch 3/100: loss: 2.4639291957270673     val_loss: 2.421719349012935
# Epoch 4/100: loss: 1.1307360044332373     val_loss: 1.1073738886200755
# Epoch 5/100: loss: 0.5264054168645773     val_loss: 0.5125710101393395
# Epoch 6/100: loss: 0.25228138924586774     val_loss: 0.24342248239113504
# Epoch 7/100: loss: 0.1277626993094142     val_loss: 0.12160110940038901
# Epoch 8/100: loss: 0.07103215275243639     val_loss: 0.06639441795665675
# Epoch 9/100: loss: 0.0450240846715369     val_loss: 0.04128588942807428
# Epoch 10/100: loss: 0.032946355594434346     val_loss: 0.029763953062456366
# Epoch 11/100: loss: 0.027191234398493004     val_loss: 0.024368743828212913
# Epoch 12/100: loss: 0.02431176450167406     val_loss: 0.021733851332061866
# Epoch 13/100: loss: 0.02274593783413705     val_loss: 0.02034261456488937
# Epoch 14/100: loss: 0.021785690922421545     val_loss: 0.019513302742795762
# Epoch 15/100: loss: 0.021109834938400848     val_loss: 0.01894044380963122
# Epoch 16/100: loss: 0.020572461235555565     val_loss: 0.018487730701893752
# Epoch 17/100: loss: 0.020107083366923528     val_loss: 0.018094656467382696
# Epoch 18/100: loss: 0.019683210500541712     val_loss: 0.017734513366460324
# Epoch 19/100: loss: 0.01928667352707172     val_loss: 0.017395558034038885
# Epoch 20/100: loss: 0.01891071172503633     val_loss: 0.01707260419197488
# Epoch 21/100: loss: 0.0185519342376407     val_loss: 0.016763295448684812
# Epoch 22/100: loss: 0.01820848997771123     val_loss: 0.01646646971094525
# Epoch 23/100: loss: 0.017879238024898658     val_loss: 0.01618145252509063
# Epoch 24/100: loss: 0.01756337129068264     val_loss: 0.015907759119450495
# Epoch 25/100: loss: 0.017260245544675135     val_loss: 0.015644973706773785
# Epoch 26/100: loss: 0.016969301493888266     val_loss: 0.0153927039579571
# Epoch 27/100: loss: 0.016690029035850134     val_loss: 0.015150566196279486
# Epoch 28/100: loss: 0.016421950635375288     val_loss: 0.014918182345511385
# Epoch 29/100: loss: 0.016164613381988647     val_loss: 0.01469518080143186
# Epoch 30/100: loss: 0.015917584996387752     val_loss: 0.01448119817492338
# Epoch 31/100: loss: 0.015680451641748156     val_loss: 0.01427588084621422
# Epoch 32/100: loss: 0.015452816567867105     val_loss: 0.014078886059096183
# Epoch 33/100: loss: 0.015234299147195016     val_loss: 0.01388988256804149
# Epoch 34/100: loss: 0.01502453410240934     val_loss: 0.01370855093207783
# Epoch 35/100: loss: 0.01482317083420824     val_loss: 0.013534583554898378
# Epoch 36/100: loss: 0.014629872807415187     val_loss: 0.013367684553063322
# Epoch 37/100: loss: 0.014444316975890192     val_loss: 0.013207569513074918
# Epoch 38/100: loss: 0.014266193236916924     val_loss: 0.013053965180073016
# Epoch 39/100: loss: 0.014095203910361308     val_loss: 0.012906609107224295
# Epoch 40/100: loss: 0.013931063240013478     val_loss: 0.012765249285124267
# Epoch 41/100: loss: 0.01377349691550146     val_loss: 0.012629643763810431
# Epoch 42/100: loss: 0.013622241613624938     val_loss: 0.012499560275455207
# Epoch 43/100: loss: 0.013477044558183004     val_loss: 0.012374775862799975
# Epoch 44/100: loss: 0.013337663097487795     val_loss: 0.012255076516416136
# Epoch 45/100: loss: 0.013203864298825347     val_loss: 0.012140256822592425
# Epoch 46/100: loss: 0.013075424559170828     val_loss: 0.012030119622817198
# Epoch 47/100: loss: 0.012952129231501274     val_loss: 0.011924475685292028
# Epoch 48/100: loss: 0.012833772266077695     val_loss: 0.01182314338857534
# Epoch 49/100: loss: 0.012720155866096244     val_loss: 0.011725948417244158
# Epoch 50/100: loss: 0.01261109015713204     val_loss: 0.01163272346933274
# Epoch 51/100: loss: 0.012506392869823     val_loss: 0.011543307975230413
# Epoch 52/100: loss: 0.012405889035263282     val_loss: 0.011457547827678093
# Epoch 53/100: loss: 0.012309410692597196     val_loss: 0.011375295122482061
# Epoch 54/100: loss: 0.012216796608324977     val_loss: 0.011296407909555786
# Epoch 55/100: loss: 0.01212789200685116     val_loss: 0.011220749953901462
# Epoch 56/100: loss: 0.01204254831182541     val_loss: 0.0111481905061495
# Epoch 57/100: loss: 0.011960622897843371     val_loss: 0.011078604082282954
# Epoch 58/100: loss: 0.011881978852092835     val_loss: 0.011011870252185696
# Epoch 59/100: loss: 0.01180648474554647     val_loss: 0.01094787343666441
# Epoch 60/100: loss: 0.011734014413319241     val_loss: 0.010886502712607807
# Epoch 61/100: loss: 0.011664446743823121     val_loss: 0.010827651625958263
# Epoch 62/100: loss: 0.011597665476366707     val_loss: 0.010771218012183786
# Epoch 63/100: loss: 0.0115335590068617     val_loss: 0.010717103823950427
# Epoch 64/100: loss: 0.01147202020131153     val_loss: 0.010665214965706936
# Epoch 65/100: loss: 0.01141294621677013     val_loss: 0.010615461134904615
# Epoch 66/100: loss: 0.011356238329472053     val_loss: 0.010567755669586827
# Epoch 67/100: loss: 0.011301801769846425     val_loss: 0.010522015402092666
# Epoch 68/100: loss: 0.011249545564139136     val_loss: 0.010478160518630021
# Epoch 69/100: loss: 0.011199382382378506     val_loss: 0.0104361144244825
# Epoch 70/100: loss: 0.011151228392430506     val_loss: 0.01039580361462461
# Epoch 71/100: loss: 0.011105003119899415     val_loss: 0.010357157549528274
# Epoch 72/100: loss: 0.011060629313639929     val_loss: 0.010320108535952652
# Epoch 73/100: loss: 0.011018032816655934     val_loss: 0.010284591612517362
# Epoch 74/100: loss: 0.010977142442170226     val_loss: 0.010250544439867601
# Epoch 75/100: loss: 0.010937889854657925     val_loss: 0.010217907195246706
# Epoch 76/100: loss: 0.010900209455644948     val_loss: 0.010186622471299752
# Epoch 77/100: loss: 0.010864038274080652     val_loss: 0.010156635178938493
# Epoch 78/100: loss: 0.010829315861101226     val_loss: 0.010127892454104639
# Epoch 79/100: loss: 0.010795984189008326     val_loss: 0.010100343568275431
# Epoch 80/100: loss: 0.010763987554293837     val_loss: 0.010073939842561257
# Epoch 81/100: loss: 0.010733272484548789     val_loss: 0.010048634565251392
# Epoch 82/100: loss: 0.010703787649100889     val_loss: 0.010024382912669562
# Epoch 83/100: loss: 0.010675483773231303     val_loss: 0.010001141873206635
# Epoch 84/100: loss: 0.010648313555827287     val_loss: 0.00997887017440302
# Epoch 85/100: loss: 0.010622231590333122     val_loss: 0.009957528212958531
# Epoch 86/100: loss: 0.010597194288867216     val_loss: 0.009937077987552211
# Epoch 87/100: loss: 0.010573159809378504     val_loss: 0.009917483034359608
# Epoch 88/100: loss: 0.01055008798572052     val_loss: 0.009898708365159149
# Epoch 89/100: loss: 0.010527940260526166     val_loss: 0.009880720407923883
# Epoch 90/100: loss: 0.010506679620771127     val_loss: 0.009863486949798942
# Epoch 91/100: loss: 0.010486270535918066     val_loss: 0.009846977082368905
# Epoch 92/100: loss: 0.010466678898538442     val_loss: 0.00983116114912338
# Epoch 93/100: loss: 0.010447871967312576     val_loss: 0.009816010695032573
# Epoch 94/100: loss: 0.010429818312312676     val_loss: 0.009801498418148149
# Epoch 95/100: loss: 0.010412487762477577     val_loss: 0.0097875981231483
# Epoch 96/100: loss: 0.010395851355191152     val_loss: 0.009774284676748879
# Epoch 97/100: loss: 0.010379881287880345     val_loss: 0.009761533964905877
# Epoch 98/100: loss: 0.010364550871551841     val_loss: 0.009749322851737224
# Epoch 99/100: loss: 0.010361559273516773     val_loss: 0.009746943411505183
# Epoch 100/100: loss: 0.010358592033483131     val_loss: 0.009744584491270082

# %%
print(f'Coefficient: {lr.coef_}\nInterception: {lr.intercept_}')
# Out:
# Coefficient: 2.9395826947153827
# Interception: 4.033304916659298

# %% [markdown]
# # Plotting to see LR in action

# %%
fig, ax = plt.subplots()
ax.scatter(X_val, y_val, color="blue", label="Data points")
line, = ax.plot([], [], "r-", linewidth=2, label="Regression Line")
ax.legend()

def update(epoch):
    coef_, intercept_ = history[epoch]
    X_fit = np.array([[0], [2]])  # Predict from 0 to 2
    y_fit = coef_ * X_fit + intercept_
    line.set_data(X_fit, y_fit)
    return line,

ani = animation.FuncAnimation(fig, update, frames=len(history), interval=100)

ani.save('ani.mp4')
# Out:
# <div id='b2e0a052-4c16-40dd-90ce-97557907095f'></div>

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('ani.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
